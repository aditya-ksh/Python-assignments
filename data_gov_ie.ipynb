# %% [markdown]
# # Datasets at data.gov.ie
#
# __Umair ul Hassan__
#
# _6 February 2024_
#
# Go to Ireland’s Open Data Portal at https://data.gov.ie/ Links to an external site.
#
# Select and download a dataset of your choice in CSV format
# Load the dataset using the read_csv() function in pandas package
# Using the describe() function to explore the summary statistics and find missing values.
# Impute the missing values if any.
# Create one graph using the matplotlib or seaborn package
# Submit your notebook to Canvas.
#
# For reference use this https://pandas.pydata.org/docs/getting_started/intro_tutorials/02_read_write.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# We have already downloaded the CSV data file from https://data.gov.ie/dataset/homelessness-report-december-2023.
#
# This data files homelessness figures for different regions and in Ireland.
#
# Using `pandas`, we load this data into a `DataFrame`

# %%
data = pd.read_csv('homelessness-report-december-2023.csv', index_col="Region")
data
# Out:
#             Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# Region
# Dublin              6754         4250           2504               1174
# Mid-East             417          257            160                 78
# Midlands             169           96             73                 22
# Mid-West             426          239            187                 73
# North-East           194          101             93                 33
# North-West           142           94             48                 15
# South-East           267          172             95                 39
# South-West           582          373            209                 70
# West                 405          226            179                 77
#
#             Adults Aged 25-44  Adults Aged 45-64  Adults Aged 65+  \
# Region
# Dublin                   3599               1872              109
# Mid-East                  180                139               20
# ...

# %% [markdown]
# We find the number of rows and columns using the `shape` attribute of the `DataFrame`. There are 9 rows and 18 columns. Notice that we have used the first column, named `Region`, in our original dataset as the `Index`.

# %%
data.shape
# Out:
# (9, 18)

# %% [markdown]
# We perform some exploratory data analysis using to the `describe()` function to find out summary statistics.

# %%
data.describe()
# Out:
#        Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# count      9.000000     9.000000       9.000000           9.000000
# mean    1039.555556   645.333333     394.222222         175.666667
# std     2147.853528  1354.880807     793.167192         375.184621
# min      142.000000    94.000000      48.000000          15.000000
# 25%      194.000000   101.000000      93.000000          33.000000
# 50%      405.000000   226.000000     160.000000          70.000000
# 75%      426.000000   257.000000     187.000000          77.000000
# max     6754.000000  4250.000000    2504.000000        1174.000000
#
#        Adults Aged 25-44  Adults Aged 45-64  Adults Aged 65+  \
# count           9.000000           9.000000         9.000000
# mean          548.888889         292.888889        22.111111
# std          1146.700423         593.527052        33.081129
# min            77.000000          42.000000         3.000000
# ...

# %% [markdown]
# We can plot the data from a column using the `matplotlib` package. In this case, first we extract the __Total Adults__ column. Then, we are using the `barh` function to create a horizontal bar chart where the labels for the y-axis are provided by the `Index` and x-axis by the `ndarray` of values in the extracted column.

# %%
# Extract on columns as a Series
tAdults = data["Total Adults"]

# Create a horizontal bar chart using index and values
plt.barh(tAdults.index, tAdults.values)

# Display the plot
plt.show()
