# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bb = yf.Ticker("BB")

# %%
data = bb.history("3mo")

# %%
closing_prices = data["Close"]
print( "Mean: " + str(closing_prices.mean()) )
print( "Standard Deviation: " + str(closing_prices.std()) )
print( "Minimum: " + str(closing_prices.min()) )
print( "Maximum: " + str(closing_prices.max()) )
print( "Median: " + str(closing_prices.median()) )
# Out:
# Mean: 3.5672580695921376
# Standard Deviation: 0.4050022013564066
# Minimum: 2.6600000858306885
# Maximum: 4.369999885559082
# Median: 3.5999999046325684

# %%
plt.plot(closing_prices)

# %%
plt.hist(closing_prices)
# Out:
# (array([ 4.,  5.,  0.,  6.,  7., 20.,  7.,  4.,  5.,  4.]),
#  array([2.66000009, 2.83100007, 3.00200005, 3.17300003, 3.34400001,
#         3.51499999, 3.68599997, 3.85699995, 4.02799993, 4.19899991,
#         4.36999989]),
#  <BarContainer object of 10 artists>)
